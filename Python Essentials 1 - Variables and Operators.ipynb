# %% [markdown]
# ## Python Essentials by Paul Chao ##

# %% [markdown]
# ## Variables 變數##

# %%
a = 3

# %%
a
# Out:
# 3

# %%
a * 3
# Out:
# 9

# %%
b = 2; a+b
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
a = "hello"

# %%
a
# Out:
# 'hello'

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-f1d53b280433> in <module>()
# ----> 1 a+b
#
# TypeError: must be str, not int

# %%
type(a)
# Out:
# str

# %% [markdown]
# ### Advanced: Everything is an object

# %%
a = int (x=5)  # instead of  int a

# %%
a
# Out:
# 5

# %%
a.__int__()  # return int itself
# Out:
# 5

# %%
b = str ("hello")

# %%
b
# Out:
# 'hello'

# %%
b.__str__()  # Return str(self)
# Out:
# 'hello'

# %%
b.__int__()  # type is not integer, variable has its own type (class)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-aa51a5ccdd08> in <module>()
# ----> 1 b.__int__()
#
# AttributeError: 'str' object has no attribute '__int__'

# %% [markdown]
# ### integer is an object
# <img src=http://archive.cnx.org/resources/bb2a28939ccd0cea1607102bb7b1b88f79e60367/1359-1030-c.jpg>
#
# ### function is an object
# <img src=https://i.stack.imgur.com/4TKpc.png>

# %% [markdown]
# ### Java (for example) ###
# <img src=https://i.stack.imgur.com/68chj.jpg>

# %%
class test(object):
    def show(self, value):
        print (value)

obj = test()
obj.show(10)

a = 10
obj.show(a)

a = 3.141592653589793
obj.show(a)

a = "hello"
obj.show(a)
# Out:
# 10
# 10
# 3.141592653589793
# hello

# %% [markdown]
# ### Applications ###

# %%
a = 3

# %%
a.__int__()
# Out:
# 3

# %%
a.__str__()
# Out:
# '3'

# %%
print (a)
# Out:
# 3

# %% [markdown]
# ## Assignment 小作業##
# ### 有個變數 a 包含存款金額, 用變數b "我的銀行存款:" 來印出銀行存款有多少

# %%
a = 100; b="我的銀行存款:"

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-f1d53b280433> in <module>()
# ----> 1 a+b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
c = b + str(a)

# %%
print(c)
# Out:
# 我的銀行存款:100

# %%
c = b + a.__str__()

# %%
print (c)
# Out:
# 我的銀行存款:100

# %%
print (b, a)
# Out:
# 我的銀行存款: 100

# %% [markdown]
# ## Operators 運算元##

# %% [markdown]
# ### Arithmetic Operations 計算###
# 7 basic binary arithmetic operators
#
# | Operator     | Name           | Description                                            |
# |--------------|----------------|--------------------------------------------------------|
# | ``a + b``    | Addition       | Sum of ``a`` and ``b``                                 |
# | ``a - b``    | Subtraction    | Difference of ``a`` and ``b``                          |
# | ``a * b``    | Multiplication | Product of ``a`` and ``b``                             |
# | ``a / b``    | True division  | Quotient of ``a`` and ``b``                            |
# | ``a // b``   | Floor division | Quotient of ``a`` and ``b``, removing fractional parts |
# | ``a % b``    | Modulus        | Integer remainder after division of ``a`` by ``b``     |
# | ``a ** b``   | Exponentiation | ``a`` raised to the power of ``b``                     |
# | ``-a``       | Negation       | The negative of ``a``                                  |
# | ``+a``       | Unary plus     | ``a`` unchanged (rarely used)                          |

# %%
(20 + 4) / ( 1.5 * 2 )
# Out:
# 8.0

# %%
print (7/2, 7//2, 7%2)
# Out:
# 3.5 3 1

# %%
print (2 ** 3)
# Out:
# 8

# %% [markdown]
# ### Assignment Operations 指定###

# %%
a = 2

# %%
a
# Out:
# 2

# %%
a = a + 2

# %%
print(a)
# Out:
# 4

# %%
a += 2 ; print(a)   # a = a + 2
# Out:
# 6

# %% [markdown]
# assignment operators:
#
# |||||
# |-|-|
# |``a += b``| ``a -= b``|``a *= b``| ``a /= b``|
# |``a //= b``| ``a %= b``|``a **= b``|``a &= b``|
# |<code>a &#124;= b</code>| ``a ^= b``|``a <<= b``| ``a >>= b``|

# %% [markdown]
# ### Comparison Operations 比較 ###
#
# Comparison of values, returns Boolean values **``True``** and **``False``**. 比較與結果、是對還是錯?
#
# | Operation     | Description                       || Operation     | Description                          |
# |---------------|-----------------------------------||---------------|--------------------------------------|
# | ``a == b``    | ``a`` equal to ``b``              || ``a != b``    | ``a`` not equal to ``b``             |
# | ``a < b``     | ``a`` less than ``b``             || ``a > b``     | ``a`` greater than ``b``             |
# | ``a <= b``    | ``a`` less than or equal to ``b`` || ``a >= b``    | ``a`` greater than or equal to ``b`` |

# %%
1 == 2
# Out:
# False

# %%
a = 3 ; b = 3

# %%
a == b
# Out:
# True

# %%
25 % 2 == 1   # even or odd  奇數還是偶數?
# Out:
# True

# %%
a = 3 ; a > 10
# Out:
# False

# %% [markdown]
# ### Boolean Operations 布林邏輯###
#  **``and``** (all True then True, 全都對嗎?)
#
#  **``or``** (True exists then True, 有對的就算對)
#
#  **``not``** (False then True, 顛倒是非)

# %% [markdown]
# #### AND ####

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
a = 10 ; b = 10

# %%
a == 10 and b == 10
# Out:
# True

# %%
a > 10 and b == 10
# Out:
# False

# %% [markdown]
# #### OR ####

# %%
True or True
# Out:
# True

# %%
print(True or False, False or True)
# Out:
# True True

# %%
a == 10 or b == 20
# Out:
# True

# %%
a > 100 or b > 100
# Out:
# False

# %% [markdown]
# #### NOT ####

# %%
(a > 5)
# Out:
# True

# %%
not (a > 5)
# Out:
# False

# %% [markdown]
# ## Assignment 小作業##
# Think about it!  想一想下面的表。
#
# <img src = http://bitbyte.space/sites/default/files/inline-images/and_or_xor_not.png>

# %% [markdown]
# ## Assignment 小作業##
# ## 用Python來算，到底3的五次方大，還是5的三次方大?
# ## 3 x 3 x 3 x 3 x 3     vs.    5 x 5 x 5   ??? ##

# %%
print (3 * 3 * 3 * 3 * 3, 5 * 5 * 5)
# Out:
# 243 125

# %%
(3 * 3 * 3 * 3 * 3) > (5 * 5 * 5)
# Out:
# True

# %%
(3 ** 5) > (5 ** 3)
# Out:
# True

# %% [markdown]
# ### Advanced - XOR (Boolean Operator)###
# There is no XOR in Python. How to do it?

# %%
True xor True
# Out:
#   File "<ipython-input-58-f6bc507e48d1>", line 1
#     True xor True
#            ^
# SyntaxError: invalid syntax

# %%
a = 5 ;  (a > 10) xor ( a > 1)  ????

# %%
print ( True != True ,  True != False , False != True , False != False )
# Out:
# False True True False

# %%
a = 5; ( a > 10 ) != ( a > 1 )
# Out:
# True

# %% [markdown]
# ## Advanced - Bitwise Operations 位元運算##
# Binary Operators (applied on integers), 二進制計算
#
# | Operator     | Name            | Description                                 |
# |--------------|-----------------|---------------------------------------------|
# | ``a & b``    | Bitwise AND     | Bits defined in both ``a`` and ``b``        |
# | <code>a &#124; b</code>| Bitwise OR      | Bits defined in ``a`` or ``b`` or both      |
# | ``a ^ b``    | Bitwise XOR     | Bits defined in ``a`` or ``b`` but not both |
# | ``a << b``   | Bit shift left  | Shift bits of ``a`` left by ``b`` units     |
# | ``a >> b``   | Bit shift right | Shift bits of ``a`` right by ``b`` units    |
# | ``~a``       | Bitwise NOT     | Bitwise negation of ``a``                          |

# %%
a = 3 ; bin(a)
# Out:
# '0b11'

# %% [markdown]
# ### Concept of Binary Numbers, Concept of A Byte 二進位、位元與位元組 ###
# <img src=http://www.pages.drexel.edu/~dj426/binary-number-values.gif>

# %%
bin(8)
# Out:
# '0b1000'

# %% [markdown]
# <img src = http://bitbyte.space/sites/default/files/inline-images/and_or_xor_not.png>

# %%
a = 0b01000011 ; type(a)
# Out:
# int

# %%
b = 0b01110010

# %%
a & b    # AND is boolean operator, instead of bitwise operator
# Out:
# 66

# %%
bin(66)
# Out:
# '0b1000010'

# %%
print ( bin( a | b ), bin( a ^ b ))
# Out:
# 0b1110011 0b110001

# %%
bin(b)
# Out:
# '0b1110010'

# %%
bin(b >> 1)
# Out:
# '0b111001'

# %%
bin(b << 1)
# Out:
# '0b11100100'

# %% [markdown]
# ### Note: Fast * 2 , / 2, power

# %% [markdown]
# ### Parallel Port ###
# <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Parallel_computer_printer_port.jpg/1200px-Parallel_computer_printer_port.jpg width=300><img src=https://upload.wikimedia.org/wikipedia/commons/thumb/e/e0/Parallel_port_pinouts.svg/350px-Parallel_port_pinouts.svg.png width=300>
